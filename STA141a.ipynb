# %% [markdown]
# <a href="https://colab.research.google.com/github/Hung-Ta-Chen/141A-final-project/blob/main/STA141a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import operator
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
import seaborn as sns

# %%
#load data from google drive
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
path = '/gdrive/MyDrive/ufc_data.csv'
ufc_data = pd.read_csv(path)

# %%
ufc_data = ufc_data.drop(["R_fighter", "B_fighter", "Referee", "date", "location", "title_bout"], axis=1)
ufc_data = ufc_data.dropna()
display(ufc_data.shape)
ufc_data.head()
# Out:
# (3914, 138)
#   Winner       weight_class  B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# 0    Red       Bantamweight  0.000000         0.000           0.420000
# 1    Red       Middleweight  0.500000         0.000           0.660000
# 4   Blue  WomenBantamweight  0.125000         0.000           0.535625
# 5   Blue        Lightweight  0.000000         0.000           0.515000
# 6   Blue       Welterweight  0.046875         0.125           0.459277
#
#    B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  \
# 0               0.495000      0.330000          0.360000       0.500000
# 1               0.305000      0.300000          0.500000       1.500000
# 4               0.578750      0.185000          0.166250       0.125000
# 5               0.473750      0.435000          0.250000       1.250000
# 6               0.404687      0.322188          0.068867       0.189453
#
#    B_avg_opp_SUB_ATT  ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# ...
